# %% [markdown]
# Create a virtual environment and then `pip install openai`

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:1234/v1", # Change this to your setting from LM Studio
    api_key="lm-studio"
)

# %%
completion = client.chat.completions.create(
    model="google/gemma-3-1b",
    messages=[
        {"role": "system", "content": "Always answer in rhymes."},
        {"role": "user", "content": "Introduce yourself."}
    ],
    temperature=2,
    max_tokens=2500,
    # seed=32,
)


print(completion)
# Out:
# ChatCompletion(id='chatcmpl-excfeyb6jxbxn139pa7rg', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Here I am, a friendly tone,\nA language model, all alone!\nI speak and learn with speedy grace,\nReady to assist, in this space. \n\nLet’s begin our conversation bright,\nExploring words and taking flight. \nAsk me anything, don't delay,\nAnd let’s have fun today!", refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1751815416, model='google/gemma-3-1b', object='chat.completion', service_tier=None, system_fingerprint='google/gemma-3-1b', usage=CompletionUsage(completion_tokens=71, prompt_tokens=18, total_tokens=89, completion_tokens_details=None, prompt_tokens_details=None), stats={})

# %%
completion_text = completion.choices[0].message.content
print(completion_text)
# Out:
# Here I am, a friendly tone,
# A language model, all alone!
# I speak and learn with speedy grace,
# Ready to assist, in this space.
#
# Let’s begin our conversation bright,
# Exploring words and taking flight.
# Ask me anything, don't delay,
# And let’s have fun today!

# %%
# Structured Output (json or XML)

character_schema = {
    "type": "json_schema",
    "json_schema": {
        "name": "characters",
        "schema": {
            "type": "object",
            "properties": {
                "characters": {
                    "type": "array",
                    "items": {
                        "type": "object",
                        "properties": {
                            "name": {"type": "string"},
                            "occupation": {"type": "string"},
                            "personality": {"type": "string"},
                            "background": {"type": "string"}
                        },
                        "required": ["name", "occupation", "personality", "background"]
                    },
                    "minItems": 1,
                }
            },
            "required": ["characters"]
        },
    }
}

messages = [
    {"role": "system", "content": "You are a helpful AI assistant."},
    {"role": "user", "content": "Create 1-3 fictional characters"}
]

response = client.chat.completions.create(
    model="gemma-3-4b-it-qat",
    messages=messages,
    temperature=0.7,
    max_tokens=2500,
    response_format=character_schema
)

print(response)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-vjpcdbdfwgfabsfb5y3ws', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{"characters": [\n  {\n    "name": "Elara Vance",\n    "occupation": "Botanical Illustrator & Amateur Astrologer",\n    "personality": "Quiet, observant, with a deeply ingrained love for the natural world and a surprisingly sharp wit. She’s prone to rambling about obscure plant species and is easily overwhelmed by crowds, preferring the solitude of her greenhouse.",\n    "background": "Elara grew up on a remote island in Scotland, raised by her grandfather, a renowned herbalist. She spent her childhood meticulously documenting every flower, leaf, and root she could find, developing an almost photographic memory for plant life."\n  },\n  {\n    "name": "Jax \'Rook\' Riley",\n    "occupation": "Freelance Salvage Pilot & Rogue Mechanic",\n    "personality": "A gruff, cynical, but secretly kind-hearted man with a dry sense of humor and a knack for fixing anything – even the most broken spaceships.",\n    "background": "Jax spent his youth bouncing around various ports and shipyards, learning to survive on the fringes. He’s driven by a desire for independence and a deep respect for machinery, often finding himself in precarious situations."\n  },\n  {\n    "name": "Seraphina \'Sera\' Moreau",\n    "occupation": "Temporal Archivist & Dream Weaver (sort of)",\n    "personality": "A whimsical, slightly anxious woman with an uncanny ability to perceive echoes and fragments of past events. She’s incredibly empathetic but struggles with the weight of what she witnesses.",\n    "background": "Sera works for a secretive organization dedicated to preserving temporal stability – essentially, she\'s a very cautious observer of time itself."\n  }\n]\n}', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1751815460, model='google/gemma-3-1b', object='chat.completion', service_tier=None, system_fingerprint='google/gemma-3-1b', usage=CompletionUsage(completion_tokens=374, prompt_tokens=24, total_tokens=398, completion_tokens_details=None, prompt_tokens_details=None), stats={})
# {"characters": [
#   {
#     "name": "Elara Vance",
#     "occupation": "Botanical Illustrator & Amateur Astrologer",
#     "personality": "Quiet, observant, with a deeply ingrained love for the natural world and a surprisingly sharp wit. She’s prone to rambling about obscure plant species and is easily overwhelmed by crowds, preferring the solitude of her greenhouse.",
#     "background": "Elara grew up on a remote island in Scotland, raised by her grandfather, a renowned herbalist. She spent her childhood meticulously documenting every flower, leaf, and root she could find, developing an almost photographic memory for plant life."
#   },
#   {
#     "name": "Jax 'Rook' Riley",
#     "occupation": "Freelance Salvage Pilot & Rogue Mechanic",
#     "personality": "A gruff, cynical, but secretly kind-hearted man with a dry sense of humor and a knack for fixing anything – even the most broken spaceships.",
#     "background": "Jax spent his youth bouncing around various ports and shipyards, learning to survive on the fringes. He’s driven by a desire for independence and a deep respect for machinery, often finding himself in precarious situations."
#   },
#   {
#     "name": "Seraphina 'Sera' Moreau",
#     "occupation": "Temporal Archivist & Dream Weaver (sort of)",
#     "personality": "A whimsical, slightly anxious woman with an uncanny ability to perceive echoes and fragments of past events. She’s incredibly empathetic but struggles with the weight of what she witnesses.",
#     "background": "Sera works for a secretive organization dedicated to preserving temporal stability – essentially, she's a very cautious observer of time itself."
#   }
# ]
# }
